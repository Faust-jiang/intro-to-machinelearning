# %%
# !git clone https://github.com/yangycpku/DeepSAM_work.git
import os

os.chdir('/content/your_repository')
# Out:
# Cloning into 'DeepSAM_work'...
# fatal: could not read Username for 'https://github.com': No such device or address
